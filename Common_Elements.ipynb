# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhratashikhre12-pixel/python-assignment/blob/main/Common_Elements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7]

common = []

for item in list1:
    if item in list2:
        common.append(item)

print("Common Elements:", common)
# Out:
# Common Elements: [4, 5]
