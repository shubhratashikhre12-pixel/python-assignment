# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhratashikhre12-pixel/python-assignment/blob/main/OOPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#What is OOPS?
#OOPS (Object-Oriented Programming System)

#OOPS is a programming concept based on objects and classes.
#It helps organize code and makes programs reusable and secure.

#Main Concepts of OOPS
#Class
#Inheritance
#Polymorphism
#Encapsulation
#Abstraction

#Difference Between Class and Object
#| Class                          | Object                      |
#| ------------------------------ | --------------------------- |
#| Blueprint/template             | Real instance of class      |
#| Logical entity                 | Physical entity             |
#| Defines properties and methods | Uses properties and methods |
