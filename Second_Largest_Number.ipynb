# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhratashikhre12-pixel/python-assignment/blob/main/Second_Largest_Number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [10, 20, 40, 30, 50]

numbers.sort()

print("Second Largest Number:", numbers[-2])
# Out:
# Second Largest Number: 40
