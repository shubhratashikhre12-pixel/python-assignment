# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhratashikhre12-pixel/python-assignment/blob/main/Factorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

factorial = 1

for i in range(1, num + 1):
    factorial = factorial * i

print("Factorial =", factorial)
# Out:
# Enter a number: 25
# Factorial = 15511210043330985984000000
