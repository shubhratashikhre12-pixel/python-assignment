# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhratashikhre12-pixel/python-assignment/blob/main/Lists_to_Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
keys = ["name", "age", "city"]
values = ["Shubhrata", 21, "Pune"]

my_dict = dict(zip(keys, values))

print(my_dict)
# Out:
# {'name': 'Shubhrata', 'age': 21, 'city': 'Pune'}
