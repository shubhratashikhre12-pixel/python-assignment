# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhratashikhre12-pixel/python-assignment/blob/main/Python_Datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Explain Data Types in Python
#What are Data Types?
#Data types define the type of value a variable can store.

#Main Data Types in Python
#| Data Type | Example    | Description                   |
#| --------- | ---------- | ----------------------------- |
#| int       | 10         | Integer numbers               |
#| float     | 10.5       | Decimal numbers               |
#| str       | "Hello"    | Text/String                   |
#| bool      | True/False | Boolean values                |
#| list      | [1,2,3]    | Ordered, mutable collection   |
#| tuple     | (1,2,3)    | Ordered, immutable collection |
#| dict      | {"a":1}    | Key-value pairs               |
#| set       | {1,2,3}    | Unordered unique items        |

#Difference Between List, Tuple, Dictionary, and NumPy

#| Feature | List            | Tuple           | Dictionary      | NumPy Array          |
#| ------- | --------------- | --------------- | --------------- | -------------------- |
#| Syntax  | []              | ()              | {}              | np.array()           |
#| Ordered | Yes             | Yes             | Yes             | Yes                  |
#| Mutable | Yes             | No              | Yes             | Yes                  |
#| Stores  | Multiple values | Multiple values | Key-value pairs | Same datatype values |
#| Speed   | Medium          | Fast            | Fast lookup     | Very Fast            |
#| Example | [1,2]           | (1,2)           | {"a":1}         | array([1,2])         |

# List
my_list = [1, 2, 3]

# Tuple
my_tuple = (1, 2, 3)

# Dictionary
my_dict = {"name": "Shubhrata", "age": 21}

# NumPy Array
import numpy as np

arr = np.array([1, 2, 3])
