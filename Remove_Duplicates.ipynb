# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhratashikhre12-pixel/python-assignment/blob/main/Remove_Duplicates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = input("Enter a string: ")

result = ""

for char in text:
    if char not in result:
        result += char

print("String after removing duplicates:", result)
# Out:
# Enter a string: available
# String after removing duplicates: avilbe
